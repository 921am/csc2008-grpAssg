# %%
import os
import pandas as pd
from pprint import pprint
from pymongo import MongoClient


def import_content(filepath, collection_name, counter_id, sort_name):
    
    collection = db[collection_name]
    collection.drop()
    
    file_res = os.path.basename(filepath)
    
    try:
        data = pd.read_csv(file_res)
        df = data.to_dict('records')
        collection.insert_many(df, ordered=False)

        print("\n\n========================================", collection_name, "========================================\n\n")

        for i in collection.find():
            pprint(i)
            print("\n")

        for i in collection.find().sort(sort_name, -1).limit(1):
            result = i[sort_name]
            print('In FOR-loop: ', result)
        print('Out FOR-loop: ', result, "\n")

        col_counter.insert_one({'name': counter_id, 'seq': result})
#         for i in col_counter.find():
#             print(i)
    except:
        col_counter.insert_one({'name': counter_id, 'seq': 0})
        print('No ', file_res, '\n')
    
    print('Counter sequence\n')
    for i in col_counter.find():
            print(i)

        
if __name__ == "__main__":
    
    client = MongoClient(host='localhost', port=27017)
    db = client['CRUD']
    col_counter = db['Counter']
    col_counter.drop()
    
    collection_name = 'Inmates'
    sort_name = 'InmateID'
    counter_id = 'inmateID'
    filepath = '/inmates.csv'
    import_content(filepath, collection_name, counter_id, sort_name)
# Out:
# ======================================== Inmates ========================================
#
#
# {'DateEntered': '1/8/2015',
#  'DateReleased': '6/27/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 1,
#  'InmateName': 'Mukasa Kiriwawanvu',
#  '_id': ObjectId('60686e164cdb763fda24ef1f')}
#
#
# {'DateEntered': '12/1/2014',
#  'DateReleased': '12/17/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 2,
#  'InmateName': 'Maximilian Kolbe',
#  '_id': ObjectId('60686e164cdb763fda24ef20')}
#
#
# {'DateEntered': '12/22/2014',
#  'DateReleased': '12/17/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 3,
#  'InmateName': 'Raphael Kalinowskin',
#  '_id': ObjectId('60686e164cdb763fda24ef21')}
#
#
# {'DateEntered': '12/16/2012',
#  'DateReleased': '11/3/2016',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 4,
#  'InmateName': 'Dorothy Day',
#  '_id': ObjectId('60686e164cdb763fda24ef22')}
#
#
# {'DateEntered': '2/7/2014',
#  'DateReleased': '10/26/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 5,
#  'InmateName': 'Jacques Fesch',
#  '_id': ObjectId('60686e164cdb763fda24ef23')}
#
#
# {'DateEntered': '1/10/2013',
#  'DateReleased': '5/18/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 6,
#  'InmateName': 'Tommy Watts',
#  '_id': ObjectId('60686e164cdb763fda24ef24')}
#
#
# {'DateEntered': '1/3/2010',
#  'DateReleased': '4/12/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 7,
#  'InmateName': 'Unity Harmon',
#  '_id': ObjectId('60686e164cdb763fda24ef25')}
#
#
# {'DateEntered': '10/29/2014',
#  'DateReleased': '12/17/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 8,
#  'InmateName': 'Talia Love',
#  '_id': ObjectId('60686e164cdb763fda24ef26')}
#
#
# {'DateEntered': '9/27/2011',
#  'DateReleased': '11/16/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 9,
#  'InmateName': 'Hubert Boyd',
#  '_id': ObjectId('60686e164cdb763fda24ef27')}
#
#
# {'DateEntered': '5/15/2012',
#  'DateReleased': '12/18/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 10,
#  'InmateName': 'Cecil Wade',
#  '_id': ObjectId('60686e164cdb763fda24ef28')}
#
#
# {'DateEntered': '10/7/2011',
#  'DateReleased': '2/11/2016',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 11,
#  'InmateName': 'Willard Nguyen',
#  '_id': ObjectId('60686e164cdb763fda24ef29')}
#
#
# {'DateEntered': '4/12/2014',
#  'DateReleased': '6/6/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 12,
#  'InmateName': 'Gale End',
#  '_id': ObjectId('60686e164cdb763fda24ef2a')}
#
#
# {'DateEntered': '6/15/2001',
#  'DateReleased': '10/5/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 13,
#  'InmateName': 'Bert Herrera',
#  '_id': ObjectId('60686e164cdb763fda24ef2b')}
#
#
# {'DateEntered': '2/13/2013',
#  'DateReleased': '12/30/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 14,
#  'InmateName': 'Maria Matthews',
#  '_id': ObjectId('60686e164cdb763fda24ef2c')}
#
#
# {'DateEntered': '12/17/2016',
#  'DateReleased': '12/23/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 15,
#  'InmateName': 'Angelica Law',
#  '_id': ObjectId('60686e164cdb763fda24ef2d')}
#
#
# {'DateEntered': '1/7/2014',
#  'DateReleased': '6/8/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 16,
#  'InmateName': 'Ash Harrison',
#  '_id': ObjectId('60686e164cdb763fda24ef2e')}
#
#
# {'DateEntered': '12/7/2013',
#  'DateReleased': '2/27/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 17,
#  'InmateName': 'Taylor Green',
#  '_id': ObjectId('60686e164cdb763fda24ef2f')}
#
#
# {'DateEntered': '1/3/2015',
#  'DateReleased': '3/16/2017',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 18,
#  'InmateName': 'Yvette Lindsey',
#  '_id': ObjectId('60686e164cdb763fda24ef30')}
#
#
# {'DateEntered': '2/19/2014',
#  'DateReleased': '2/7/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 19,
#  'InmateName': 'Gabrielle Johnson',
#  '_id': ObjectId('60686e164cdb763fda24ef31')}
#
#
# {'DateEntered': '5/3/2014',
#  'DateReleased': '2/5/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 20,
#  'InmateName': 'Carmen Snyder',
#  '_id': ObjectId('60686e164cdb763fda24ef32')}
#
#
# {'DateEntered': '2/27/2012',
#  'DateReleased': '3/21/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 21,
#  'InmateName': 'Windsor Welch',
#  '_id': ObjectId('60686e164cdb763fda24ef33')}
#
#
# {'DateEntered': '10/27/2011',
#  'DateReleased': '9/29/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 22,
#  'InmateName': 'Alice Horton',
#  '_id': ObjectId('60686e164cdb763fda24ef34')}
#
#
# {'DateEntered': '10/7/2013',
#  'DateReleased': '10/8/2021',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 23,
#  'InmateName': 'Addison Tillery',
#  '_id': ObjectId('60686e164cdb763fda24ef35')}
#
#
# {'DateEntered': '2/27/2012',
#  'DateReleased': '11/19/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 24,
#  'InmateName': 'Chase Oliver',
#  '_id': ObjectId('60686e164cdb763fda24ef36')}
#
#
# {'DateEntered': '2/6/2010',
#  'DateReleased': '2/9/2020',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 25,
#  'InmateName': 'Tyler Wright',
#  '_id': ObjectId('60686e164cdb763fda24ef37')}
#
#
# {'DateEntered': '12/17/2008',
#  'DateReleased': '12/17/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 26,
#  'InmateName': 'Priscilla Terry',
#  '_id': ObjectId('60686e164cdb763fda24ef38')}
#
#
# {'DateEntered': '1/30/2013',
#  'DateReleased': '2/20/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 27,
#  'InmateName': 'Pearl Hubbard',
#  '_id': ObjectId('60686e164cdb763fda24ef39')}
#
#
# {'DateEntered': '2/26/2012',
#  'DateReleased': '12/27/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 28,
#  'InmateName': 'Harley Wallaker',
#  '_id': ObjectId('60686e164cdb763fda24ef3a')}
#
#
# {'DateEntered': '2/17/2013',
#  'DateReleased': '2/1/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 29,
#  'InmateName': 'Ellen Males',
#  '_id': ObjectId('60686e164cdb763fda24ef3b')}
#
#
# {'DateEntered': '4/14/2014',
#  'DateReleased': '10/10/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 30,
#  'InmateName': 'Gareth Mccarthy',
#  '_id': ObjectId('60686e164cdb763fda24ef3c')}
#
#
# {'DateEntered': '10/10/2001',
#  'DateReleased': '2/18/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 31,
#  'InmateName': 'Kevin Schuman',
#  '_id': ObjectId('60686e164cdb763fda24ef3d')}
#
#
# {'DateEntered': '9/2/2002',
#  'DateReleased': '11/11/2018',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 32,
#  'InmateName': 'Clif Garraway',
#  '_id': ObjectId('60686e164cdb763fda24ef3e')}
#
#
# {'DateEntered': '12/25/2006',
#  'DateReleased': '2/22/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 33,
#  'InmateName': 'Margaret Holden',
#  '_id': ObjectId('60686e164cdb763fda24ef3f')}
#
#
# {'DateEntered': '3/9/2009',
#  'DateReleased': '4/1/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 34,
#  'InmateName': 'Ralph Rios',
#  '_id': ObjectId('60686e164cdb763fda24ef40')}
#
#
# {'DateEntered': '8/12/2012',
#  'DateReleased': '6/17/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 35,
#  'InmateName': 'Joanna Erickson',
#  '_id': ObjectId('60686e164cdb763fda24ef41')}
#
#
# {'DateEntered': '5/4/2007',
#  'DateReleased': '4/3/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 36,
#  'InmateName': 'Bud Fraley',
#  '_id': ObjectId('60686e164cdb763fda24ef42')}
#
#
# {'DateEntered': '7/9/2006',
#  'DateReleased': '8/2/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 37,
#  'InmateName': 'Darlene Alvarez',
#  '_id': ObjectId('60686e164cdb763fda24ef43')}
#
#
# {'DateEntered': '10/8/2009',
#  'DateReleased': '4/15/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 38,
#  'InmateName': 'Addison Estrada',
#  '_id': ObjectId('60686e164cdb763fda24ef44')}
#
#
# {'DateEntered': '7/30/1999',
#  'DateReleased': '6/29/2017',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 39,
#  'InmateName': 'Doroes Migos',
#  '_id': ObjectId('60686e164cdb763fda24ef45')}
#
#
# {'DateEntered': '6/29/2007',
#  'DateReleased': '6/14/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 40,
#  'InmateName': 'Haylee Chaz',
#  '_id': ObjectId('60686e164cdb763fda24ef46')}
#
#
# {'DateEntered': '12/10/2001',
#  'DateReleased': '5/24/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 41,
#  'InmateName': 'Jaylee Chavez',
#  '_id': ObjectId('60686e164cdb763fda24ef47')}
#
#
# {'DateEntered': '9/25/2009',
#  'DateReleased': '10/10/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 42,
#  'InmateName': 'Wilona Trivett',
#  '_id': ObjectId('60686e164cdb763fda24ef48')}
#
#
# {'DateEntered': '1/29/2015',
#  'DateReleased': '2/27/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 43,
#  'InmateName': 'Nicole Bates',
#  '_id': ObjectId('60686e164cdb763fda24ef49')}
#
#
# {'DateEntered': '2/23/2007',
#  'DateReleased': '4/10/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 44,
#  'InmateName': 'Jerome Howard',
#  '_id': ObjectId('60686e164cdb763fda24ef4a')}
#
#
# {'DateEntered': '4/22/2010',
#  'DateReleased': '10/27/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 45,
#  'InmateName': 'Shirley Colon',
#  '_id': ObjectId('60686e164cdb763fda24ef4b')}
#
#
# {'DateEntered': '11/1/2000',
#  'DateReleased': '4/7/2017',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 46,
#  'InmateName': 'Mike Rogers',
#  '_id': ObjectId('60686e164cdb763fda24ef4c')}
#
#
# {'DateEntered': '1/10/2004',
#  'DateReleased': '1/2/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 47,
#  'InmateName': 'Ursula Yates',
#  '_id': ObjectId('60686e164cdb763fda24ef4d')}
#
#
# {'DateEntered': '5/9/2005',
#  'DateReleased': '2/25/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 48,
#  'InmateName': 'Harmony McDaniel',
#  '_id': ObjectId('60686e164cdb763fda24ef4e')}
#
#
# {'DateEntered': '8/6/2005',
#  'DateReleased': '5/3/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 49,
#  'InmateName': 'Maynard Flatcher',
#  '_id': ObjectId('60686e164cdb763fda24ef4f')}
#
#
# {'DateEntered': '4/9/2014',
#  'DateReleased': '8/8/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 50,
#  'InmateName': 'Cassian Schwartz',
#  '_id': ObjectId('60686e164cdb763fda24ef50')}
#
#
# {'DateEntered': '6/28/2014',
#  'DateReleased': '2/23/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 51,
#  'InmateName': 'Violet Davis',
#  '_id': ObjectId('60686e164cdb763fda24ef51')}
#
#
# {'DateEntered': '7/12/2003',
#  'DateReleased': '1/7/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 52,
#  'InmateName': 'Priscilla Macy',
#  '_id': ObjectId('60686e164cdb763fda24ef52')}
#
#
# {'DateEntered': '4/9/2014',
#  'DateReleased': '8/16/2015',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 53,
#  'InmateName': 'Harding Lindsey',
#  '_id': ObjectId('60686e164cdb763fda24ef53')}
#
#
# {'DateEntered': '10/17/2014',
#  'DateReleased': '4/16/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 54,
#  'InmateName': 'John Morison',
#  '_id': ObjectId('60686e164cdb763fda24ef54')}
#
#
# {'DateEntered': '8/27/2013',
#  'DateReleased': '2/25/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 55,
#  'InmateName': 'Bruce Buffer',
#  '_id': ObjectId('60686e164cdb763fda24ef55')}
#
#
# {'DateEntered': '10/24/2007',
#  'DateReleased': '4/10/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 56,
#  'InmateName': 'John Robbins',
#  '_id': ObjectId('60686e164cdb763fda24ef56')}
#
#
# {'DateEntered': '1/3/1998',
#  'DateReleased': '2/8/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 57,
#  'InmateName': 'Austin Jimenez',
#  '_id': ObjectId('60686e164cdb763fda24ef57')}
#
#
# {'DateEntered': '3/29/2008',
#  'DateReleased': '10/7/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 58,
#  'InmateName': 'Wren Madron',
#  '_id': ObjectId('60686e164cdb763fda24ef58')}
#
#
# {'DateEntered': '3/29/2006',
#  'DateReleased': '8/25/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 59,
#  'InmateName': 'Gene George',
#  '_id': ObjectId('60686e164cdb763fda24ef59')}
#
#
# {'DateEntered': '10/3/2008',
#  'DateReleased': '12/16/2017',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 60,
#  'InmateName': 'Donald Wood',
#  '_id': ObjectId('60686e164cdb763fda24ef5a')}
#
#
# {'DateEntered': '8/30/2006',
#  'DateReleased': '4/19/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 61,
#  'InmateName': 'Hayley Hayward',
#  '_id': ObjectId('60686e164cdb763fda24ef5b')}
#
#
# {'DateEntered': '4/4/2014',
#  'DateReleased': '2/28/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 62,
#  'InmateName': 'Imogem Sims',
#  '_id': ObjectId('60686e164cdb763fda24ef5c')}
#
#
# {'DateEntered': '11/25/2008',
#  'DateReleased': '3/3/2020',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 63,
#  'InmateName': 'Nawal Dillard',
#  '_id': ObjectId('60686e164cdb763fda24ef5d')}
#
#
# {'DateEntered': '7/29/2007',
#  'DateReleased': '1/27/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 64,
#  'InmateName': 'Bartosz Duarte',
#  '_id': ObjectId('60686e164cdb763fda24ef5e')}
#
#
# {'DateEntered': '3/7/1999',
#  'DateReleased': '10/22/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 65,
#  'InmateName': 'Bradley Howe',
#  '_id': ObjectId('60686e164cdb763fda24ef5f')}
#
#
# {'DateEntered': '8/21/2003',
#  'DateReleased': '10/20/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 66,
#  'InmateName': 'Elijah Benton',
#  '_id': ObjectId('60686e164cdb763fda24ef60')}
#
#
# {'DateEntered': '7/4/2014',
#  'DateReleased': '6/5/2017',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 67,
#  'InmateName': 'Evie Cooper',
#  '_id': ObjectId('60686e164cdb763fda24ef61')}
#
#
# {'DateEntered': '5/24/2012',
#  'DateReleased': '5/28/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 68,
#  'InmateName': 'Tommie Mcfarlane',
#  '_id': ObjectId('60686e164cdb763fda24ef62')}
#
#
# {'DateEntered': '9/7/2012',
#  'DateReleased': '3/18/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 69,
#  'InmateName': 'Brook Burnett',
#  '_id': ObjectId('60686e164cdb763fda24ef63')}
#
#
# {'DateEntered': '6/9/2007',
#  'DateReleased': '4/21/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 70,
#  'InmateName': 'Hugh Cobb',
#  '_id': ObjectId('60686e164cdb763fda24ef64')}
#
#
# {'DateEntered': '2/6/2008',
#  'DateReleased': '10/21/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 71,
#  'InmateName': 'Tara Robertson',
#  '_id': ObjectId('60686e164cdb763fda24ef65')}
#
#
# {'DateEntered': '3/25/2010',
#  'DateReleased': '1/12/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 72,
#  'InmateName': 'Alexandru Cordova',
#  '_id': ObjectId('60686e164cdb763fda24ef66')}
#
#
# {'DateEntered': '12/9/2011',
#  'DateReleased': '2/3/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 73,
#  'InmateName': 'Dennis Irving',
#  '_id': ObjectId('60686e164cdb763fda24ef67')}
#
#
# {'DateEntered': '4/3/2013',
#  'DateReleased': '11/15/2018',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 74,
#  'InmateName': 'Viktoria Norton',
#  '_id': ObjectId('60686e164cdb763fda24ef68')}
#
#
# {'DateEntered': '8/25/2004',
#  'DateReleased': '5/25/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 75,
#  'InmateName': 'Roshni Clay',
#  '_id': ObjectId('60686e164cdb763fda24ef69')}
#
#
# {'DateEntered': '6/24/2004',
#  'DateReleased': '8/12/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 76,
#  'InmateName': 'Mukasa Kiriwawanvu',
#  '_id': ObjectId('60686e164cdb763fda24ef6a')}
#
#
# {'DateEntered': '3/5/2003',
#  'DateReleased': '4/9/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 77,
#  'InmateName': 'Matteo Laing',
#  '_id': ObjectId('60686e164cdb763fda24ef6b')}
#
#
# {'DateEntered': '1/3/2012',
#  'DateReleased': '7/7/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 78,
#  'InmateName': 'Alton Howarth',
#  '_id': ObjectId('60686e164cdb763fda24ef6c')}
#
#
# {'DateEntered': '10/19/2008',
#  'DateReleased': '6/25/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 79,
#  'InmateName': 'Ted Esquivel',
#  '_id': ObjectId('60686e164cdb763fda24ef6d')}
#
#
# {'DateEntered': '10/10/2006',
#  'DateReleased': '11/13/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 80,
#  'InmateName': 'Jaden Burks',
#  '_id': ObjectId('60686e164cdb763fda24ef6e')}
#
#
# {'DateEntered': '3/23/2010',
#  'DateReleased': '8/3/2016',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 81,
#  'InmateName': 'Penny Pruitt',
#  '_id': ObjectId('60686e164cdb763fda24ef6f')}
#
#
# {'DateEntered': '5/5/2006',
#  'DateReleased': '9/2/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 82,
#  'InmateName': 'Brook Wilkins',
#  '_id': ObjectId('60686e164cdb763fda24ef70')}
#
#
# {'DateEntered': '4/7/2011',
#  'DateReleased': '2/17/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 83,
#  'InmateName': 'Charlton Whitmore',
#  '_id': ObjectId('60686e164cdb763fda24ef71')}
#
#
# {'DateEntered': '9/16/2007',
#  'DateReleased': '7/18/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 84,
#  'InmateName': 'Raheel Mill',
#  '_id': ObjectId('60686e164cdb763fda24ef72')}
#
#
# {'DateEntered': '10/10/2011',
#  'DateReleased': '8/3/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 85,
#  'InmateName': 'Nishat Nixon',
#  '_id': ObjectId('60686e164cdb763fda24ef73')}
#
#
# {'DateEntered': '3/4/2013',
#  'DateReleased': '8/13/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 86,
#  'InmateName': 'Zac Clayton',
#  '_id': ObjectId('60686e164cdb763fda24ef74')}
#
#
# {'DateEntered': '3/8/2012',
#  'DateReleased': '7/17/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 87,
#  'InmateName': 'Bayley Stephens',
#  '_id': ObjectId('60686e164cdb763fda24ef75')}
#
#
# {'DateEntered': '2/3/2011',
#  'DateReleased': '4/19/2019',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 88,
#  'InmateName': 'Selina East',
#  '_id': ObjectId('60686e164cdb763fda24ef76')}
#
#
# {'DateEntered': '11/10/2010',
#  'DateReleased': '4/22/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 89,
#  'InmateName': 'Mahima Henderson',
#  '_id': ObjectId('60686e164cdb763fda24ef77')}
#
#
# {'DateEntered': '11/22/1999',
#  'DateReleased': '10/13/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 90,
#  'InmateName': 'Callam Samuels',
#  '_id': ObjectId('60686e164cdb763fda24ef78')}
#
#
# {'DateEntered': '2/22/2010',
#  'DateReleased': '6/4/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 91,
#  'InmateName': 'Taha Michael',
#  '_id': ObjectId('60686e164cdb763fda24ef79')}
#
#
# {'DateEntered': '2/17/1999',
#  'DateReleased': '3/5/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 92,
#  'InmateName': 'Nazifa Valenzuela',
#  '_id': ObjectId('60686e164cdb763fda24ef7a')}
#
#
# {'DateEntered': '1/11/2001',
#  'DateReleased': '6/9/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 93,
#  'InmateName': 'Hallie Bone',
#  '_id': ObjectId('60686e164cdb763fda24ef7b')}
#
#
# {'DateEntered': '2/8/2005',
#  'DateReleased': '4/5/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 94,
#  'InmateName': 'Catriona Ferguson',
#  '_id': ObjectId('60686e164cdb763fda24ef7c')}
#
#
# {'DateEntered': '4/30/2003',
#  'DateReleased': '5/13/2019',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 95,
#  'InmateName': 'Amrita Riley',
#  '_id': ObjectId('60686e164cdb763fda24ef7d')}
#
#
# {'DateEntered': '9/23/2011',
#  'DateReleased': '11/26/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 96,
#  'InmateName': 'Jorgie Cisneros',
#  '_id': ObjectId('60686e164cdb763fda24ef7e')}
#
#
# {'DateEntered': '7/15/1999',
#  'DateReleased': '7/27/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 97,
#  'InmateName': 'Kody Tapia',
#  '_id': ObjectId('60686e164cdb763fda24ef7f')}
#
#
# {'DateEntered': '10/14/2005',
#  'DateReleased': '9/17/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 98,
#  'InmateName': 'Franklyn Sharpe',
#  '_id': ObjectId('60686e164cdb763fda24ef80')}
#
#
# {'DateEntered': '10/27/2011',
#  'DateReleased': '7/21/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 99,
#  'InmateName': 'Liya Tang',
#  '_id': ObjectId('60686e164cdb763fda24ef81')}
#
#
# {'DateEntered': '8/1/2000',
#  'DateReleased': '5/29/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 100,
#  'InmateName': 'Linzi Mathews',
#  '_id': ObjectId('60686e164cdb763fda24ef82')}
#
#
# {'DateEntered': '10/26/2004',
#  'DateReleased': '11/14/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 101,
#  'InmateName': 'Jaydon Shaffer',
#  '_id': ObjectId('60686e164cdb763fda24ef83')}
#
#
# {'DateEntered': '8/19/2007',
#  'DateReleased': '3/29/2019',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 102,
#  'InmateName': 'Shelley Leigh',
#  '_id': ObjectId('60686e164cdb763fda24ef84')}
#
#
# {'DateEntered': '2/28/2006',
#  'DateReleased': '7/21/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 103,
#  'InmateName': 'Deanne Morrison',
#  '_id': ObjectId('60686e164cdb763fda24ef85')}
#
#
# {'DateEntered': '7/15/2010',
#  'DateReleased': '8/22/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 104,
#  'InmateName': 'Neil Wood',
#  '_id': ObjectId('60686e164cdb763fda24ef86')}
#
#
# {'DateEntered': '3/25/2002',
#  'DateReleased': '6/29/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 105,
#  'InmateName': 'Rebekah Rahman',
#  '_id': ObjectId('60686e164cdb763fda24ef87')}
#
#
# {'DateEntered': '12/25/2002',
#  'DateReleased': '1/13/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 106,
#  'InmateName': 'Uwais Powers',
#  '_id': ObjectId('60686e164cdb763fda24ef88')}
#
#
# {'DateEntered': '7/15/2013',
#  'DateReleased': '9/28/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 107,
#  'InmateName': 'Hadiqa Baxter',
#  '_id': ObjectId('60686e164cdb763fda24ef89')}
#
#
# {'DateEntered': '10/30/2013',
#  'DateReleased': '11/23/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 108,
#  'InmateName': 'Ian Alvarado',
#  '_id': ObjectId('60686e164cdb763fda24ef8a')}
#
#
# {'DateEntered': '1/14/2002',
#  'DateReleased': '4/12/2016',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 109,
#  'InmateName': 'Phoebe Mccallum',
#  '_id': ObjectId('60686e164cdb763fda24ef8b')}
#
#
# {'DateEntered': '1/14/2002',
#  'DateReleased': '11/12/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 110,
#  'InmateName': 'Matteo Wilson',
#  '_id': ObjectId('60686e164cdb763fda24ef8c')}
#
#
# {'DateEntered': '6/3/2003',
#  'DateReleased': '4/14/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 111,
#  'InmateName': 'Nathaniel Hilton',
#  '_id': ObjectId('60686e164cdb763fda24ef8d')}
#
#
# {'DateEntered': '8/29/2004',
#  'DateReleased': '3/27/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 112,
#  'InmateName': 'Donte Trevino',
#  '_id': ObjectId('60686e164cdb763fda24ef8e')}
#
#
# {'DateEntered': '11/22/2003',
#  'DateReleased': '6/16/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 113,
#  'InmateName': 'Shauna Briggs',
#  '_id': ObjectId('60686e164cdb763fda24ef8f')}
#
#
# {'DateEntered': '9/7/2002',
#  'DateReleased': '12/21/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 114,
#  'InmateName': 'Manraj Maxwell',
#  '_id': ObjectId('60686e164cdb763fda24ef90')}
#
#
# {'DateEntered': '10/6/2009',
#  'DateReleased': '7/1/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 115,
#  'InmateName': 'Onur Mccray',
#  '_id': ObjectId('60686e164cdb763fda24ef91')}
#
#
# {'DateEntered': '11/11/2007',
#  'DateReleased': '5/9/2017',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 116,
#  'InmateName': 'Aya Reed',
#  '_id': ObjectId('60686e164cdb763fda24ef92')}
#
#
# {'DateEntered': '12/8/2009',
#  'DateReleased': '3/23/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 117,
#  'InmateName': 'Eesha Duffy',
#  '_id': ObjectId('60686e164cdb763fda24ef93')}
#
#
# {'DateEntered': '1/12/2009',
#  'DateReleased': '8/14/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 118,
#  'InmateName': 'Gracie Finley',
#  '_id': ObjectId('60686e164cdb763fda24ef94')}
#
#
# {'DateEntered': '8/3/2008',
#  'DateReleased': '2/8/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 119,
#  'InmateName': 'Marek Beltran',
#  '_id': ObjectId('60686e164cdb763fda24ef95')}
#
#
# {'DateEntered': '2/9/2005',
#  'DateReleased': '9/23/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 120,
#  'InmateName': 'Balraj Marin',
#  '_id': ObjectId('60686e164cdb763fda24ef96')}
#
#
# {'DateEntered': '9/6/1998',
#  'DateReleased': '6/14/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 121,
#  'InmateName': 'Macaulay Conley',
#  '_id': ObjectId('60686e164cdb763fda24ef97')}
#
#
# {'DateEntered': '9/3/2007',
#  'DateReleased': '3/18/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 122,
#  'InmateName': 'Yvie Randall',
#  '_id': ObjectId('60686e164cdb763fda24ef98')}
#
#
# {'DateEntered': '12/18/1998',
#  'DateReleased': '8/11/2016',
#  'DrugOffender': True,
#  'Gender': 'F',
#  'InmateID': 123,
#  'InmateName': 'Vihaan Brookes',
#  '_id': ObjectId('60686e164cdb763fda24ef99')}
#
#
# {'DateEntered': '3/17/2015',
#  'DateReleased': '12/7/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 124,
#  'InmateName': 'Stephanie Hughes',
#  '_id': ObjectId('60686e164cdb763fda24ef9a')}
#
#
# {'DateEntered': '12/13/2000',
#  'DateReleased': '1/15/2019',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 125,
#  'InmateName': 'Louis Bonner',
#  '_id': ObjectId('60686e164cdb763fda24ef9b')}
#
#
# {'DateEntered': '9/10/2001',
#  'DateReleased': '2/12/2018',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 126,
#  'InmateName': 'Sanaa Mcculloch',
#  '_id': ObjectId('60686e164cdb763fda24ef9c')}
#
#
# {'DateEntered': '6/29/2009',
#  'DateReleased': '3/14/2017',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 127,
#  'InmateName': 'Dottie Eastwood',
#  '_id': ObjectId('60686e164cdb763fda24ef9d')}
#
#
# {'DateEntered': '11/11/2011',
#  'DateReleased': '8/14/2016',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 128,
#  'InmateName': 'Logan Magana',
#  '_id': ObjectId('60686e164cdb763fda24ef9e')}
#
#
# {'DateEntered': '12/12/1999',
#  'DateReleased': '12/17/2015',
#  'DrugOffender': True,
#  'Gender': 'M',
#  'InmateID': 129,
#  'InmateName': 'Campbell Poole',
#  '_id': ObjectId('60686e164cdb763fda24ef9f')}
#
#
# In FOR-loop:  129
# Out FOR-loop:  129
#
# Counter sequence
#
# {'_id': ObjectId('60686e164cdb763fda24efa0'), 'name': 'inmateID', 'seq': 129}

# %%
    collection_name = 'Users'
    sort_name = 'UserID'
    counter_id = 'userID'
    filepath = '/users.csv'
    import_content(filepath, collection_name, counter_id, sort_name)
# Out:
# No  users.csv
#
# Counter sequence
#
# {'_id': ObjectId('60686e164cdb763fda24efa0'), 'name': 'inmateID', 'seq': 129}
# {'_id': ObjectId('60686e164cdb763fda24efa1'), 'name': 'userID', 'seq': 0}

# %%
    collection_name = 'AcadProgramme'
    sort_name = 'ProgID'
    counter_id = 'acadProjID'
    filepath = '/acadProgramme.csv'
    import_content(filepath, collection_name, counter_id, sort_name)
# Out:
# ======================================== AcadProgramme ========================================
#
#
# {'EndDate': '12/23/2015',
#  'ProgDescrip': 'GCE O-Levels',
#  'ProgID': 1,
#  'ProgName': 'O-Level',
#  'StartDate': '4/1/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa2')}
#
#
# {'EndDate': '9/26/2015',
#  'ProgDescrip': 'GCE A-Levels',
#  'ProgID': 2,
#  'ProgName': 'A-Level',
#  'StartDate': '1/9/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa3')}
#
#
# {'EndDate': '12/14/2015',
#  'ProgDescrip': 'Private diploma',
#  'ProgID': 3,
#  'ProgName': 'Private Diploma',
#  'StartDate': '1/21/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa4')}
#
#
# {'EndDate': '10/25/2015',
#  'ProgDescrip': 'Degree Programme',
#  'ProgID': 4,
#  'ProgName': 'Undergraduate Degree',
#  'StartDate': '2/1/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa5')}
#
#
# {'EndDate': '10/30/2015',
#  'ProgDescrip': 'Professional Certificate',
#  'ProgID': 5,
#  'ProgName': 'Technical Certification',
#  'StartDate': '1/3/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa6')}
#
#
# In FOR-loop:  5
# Out FOR-loop:  5
#
# Counter sequence
#
# {'_id': ObjectId('60686e164cdb763fda24efa0'), 'name': 'inmateID', 'seq': 129}
# {'_id': ObjectId('60686e164cdb763fda24efa1'), 'name': 'userID', 'seq': 0}
# {'_id': ObjectId('60686e164cdb763fda24efa7'), 'name': 'acadProjID', 'seq': 5}

# %%
    collection_name = 'DrugRehabProgramme'
    sort_name = 'ProgID'
    counter_id = 'drugRehabProjID'
    filepath = '/drugRehabProgramme.csv'
    import_content(filepath, collection_name, counter_id, sort_name)
# Out:
# ======================================== DrugRehabProgramme ========================================
#
#
# {'EndDate': '11/20/2015',
#  'ProgDescrip': 'Substance abuse programmes',
#  'ProgID': 1,
#  'ProgName': 'Alcohol Addiction Treatment',
#  'StartDate': '4/10/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa8')}
#
#
# {'EndDate': '11/18/2015',
#  'ProgDescrip': 'Substance abuse programmes',
#  'ProgID': 2,
#  'ProgName': 'Drug Addiction Treatment',
#  'StartDate': '4/10/2015',
#  '_id': ObjectId('60686e164cdb763fda24efa9')}
#
#
# {'EndDate': '12/15/2015',
#  'ProgDescrip': 'Gambling programmes',
#  'ProgID': 3,
#  'ProgName': 'Process Addiction Treatment',
#  'StartDate': '4/12/2015',
#  '_id': ObjectId('60686e164cdb763fda24efaa')}
#
#
# {'EndDate': '11/22/2015',
#  'ProgDescrip': 'Relapse prevention Programme',
#  'ProgID': 4,
#  'ProgName': 'Relapse Prevention',
#  'StartDate': '4/6/2015',
#  '_id': ObjectId('60686e164cdb763fda24efab')}
#
#
# {'EndDate': '11/30/2015',
#  'ProgDescrip': 'Family programmes',
#  'ProgID': 5,
#  'ProgName': 'Family Programme',
#  'StartDate': '4/8/2015',
#  '_id': ObjectId('60686e164cdb763fda24efac')}
#
#
# In FOR-loop:  5
# Out FOR-loop:  5
#
# Counter sequence
#
# {'_id': ObjectId('60686e164cdb763fda24efa0'), 'name': 'inmateID', 'seq': 129}
# {'_id': ObjectId('60686e164cdb763fda24efa1'), 'name': 'userID', 'seq': 0}
# {'_id': ObjectId('60686e164cdb763fda24efa7'), 'name': 'acadProjID', 'seq': 5}
# {'_id': ObjectId('60686e164cdb763fda24efad'), 'name': 'drugRehabProjID', 'seq': 5}

# %%
    collection_name = 'VocationalProgramme'
    sort_name = 'ProgID'
    counter_id = 'vocationalProjID'
    filepath = '/vocationalProgramme.csv'
    import_content(filepath, collection_name, counter_id, sort_name)
# Out:
# ======================================== VocationalProgramme ========================================
#
#
# {'EndDate': '12/5/2015',
#  'ProgDescrip': 'Applied and pure science vocational course',
#  'ProgID': 1,
#  'ProgName': 'Biology',
#  'StartDate': '3/12/2015',
#  '_id': ObjectId('60686e164cdb763fda24efae')}
#
#
# {'EndDate': '11/1/2015',
#  'ProgDescrip': 'Applied and pure science vocational course',
#  'ProgID': 2,
#  'ProgName': 'Earth Sciences',
#  'StartDate': '2/14/2015',
#  '_id': ObjectId('60686e164cdb763fda24efaf')}
#
#
# {'EndDate': '12/22/2015',
#  'ProgDescrip': 'Architecture and construction vocational course',
#  'ProgID': 3,
#  'ProgName': 'Architecture',
#  'StartDate': '3/1/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb0')}
#
#
# {'EndDate': '11/29/2015',
#  'ProgDescrip': 'Architecture and construction vocational course',
#  'ProgID': 4,
#  'ProgName': 'Property Management',
#  'StartDate': '2/28/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb1')}
#
#
# {'EndDate': '12/22/2015',
#  'ProgDescrip': 'Business Management vocational course',
#  'ProgID': 5,
#  'ProgName': 'Accounting',
#  'StartDate': '2/5/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb2')}
#
#
# {'EndDate': '11/29/2015',
#  'ProgDescrip': 'Business Management vocational course',
#  'ProgID': 6,
#  'ProgName': 'Office Administration',
#  'StartDate': '3/1/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb3')}
#
#
# {'EndDate': '12/21/2015',
#  'ProgDescrip': 'Computer Science and IT vocational course',
#  'ProgID': 7,
#  'ProgName': 'Software',
#  'StartDate': '1/13/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb4')}
#
#
# {'EndDate': '12/2/2015',
#  'ProgDescrip': 'Creative Arts and Design vocational course',
#  'ProgID': 8,
#  'ProgName': 'Art Administration',
#  'StartDate': '3/7/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb5')}
#
#
# {'EndDate': '11/13/2015',
#  'ProgDescrip': 'Computer Science and IT vocational course',
#  'ProgID': 9,
#  'ProgName': 'Interior Design',
#  'StartDate': '2/23/2015',
#  '_id': ObjectId('60686e164cdb763fda24efb6')}
#
#
# In FOR-loop:  9
# Out FOR-loop:  9
#
# Counter sequence
#
# {'_id': ObjectId('60686e164cdb763fda24efa0'), 'name': 'inmateID', 'seq': 129}
# {'_id': ObjectId('60686e164cdb763fda24efa1'), 'name': 'userID', 'seq': 0}
# {'_id': ObjectId('60686e164cdb763fda24efa7'), 'name': 'acadProjID', 'seq': 5}
# {'_id': ObjectId('60686e164cdb763fda24efad'), 'name': 'drugRehabProjID', 'seq': 5}
# {'_id': ObjectId('60686e164cdb763fda24efb7'), 'name': 'vocationalProjID', 'seq': 9}

# %%
    collection_name = 'InmateProgress'
    sort_name = 'InmateProgressID'
    counter_id = 'inmateProjID'
    filepath = '/inmateProgress.csv'
    import_content(filepath, collection_name, counter_id, sort_name)
# Out:
# ======================================== InmateProgress ========================================
#
#
# {'AcadProgID': 1,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 1,
#  'InmateProgressID': 1,
#  'RehabProgID': 2,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 1,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efb8')}
#
#
# {'AcadProgID': 3,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 2,
#  'InmateProgressID': 2,
#  'RehabProgID': 2,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 2,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efb9')}
#
#
# {'AcadProgID': 3,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 3,
#  'InmateProgressID': 3,
#  'RehabProgID': 5,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 3,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efba')}
#
#
# {'AcadProgID': 1,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 4,
#  'InmateProgressID': 4,
#  'RehabProgID': 1,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 7,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efbb')}
#
#
# {'AcadProgID': 5,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 5,
#  'InmateProgressID': 5,
#  'RehabProgID': 3,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 4,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efbc')}
#
#
# {'AcadProgID': 1,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 53,
#  'InmateProgressID': 6,
#  'RehabProgID': 2,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 8,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efbd')}
#
#
# {'AcadProgID': 1,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 19,
#  'InmateProgressID': 7,
#  'RehabProgID': 4,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 6,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efbe')}
#
#
# {'AcadProgID': 5,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 15,
#  'InmateProgressID': 8,
#  'RehabProgID': 5,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 3,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efbf')}
#
#
# {'AcadProgID': 5,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 18,
#  'InmateProgressID': 9,
#  'RehabProgID': 1,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 1,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc0')}
#
#
# {'AcadProgID': 1,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 50,
#  'InmateProgressID': 10,
#  'RehabProgID': 3,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 4,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc1')}
#
#
# {'AcadProgID': 3,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 30,
#  'InmateProgressID': 11,
#  'RehabProgID': 2,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 1,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc2')}
#
#
# {'AcadProgID': 5,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 55,
#  'InmateProgressID': 12,
#  'RehabProgID': 4,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 2,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc3')}
#
#
# {'AcadProgID': 3,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 20,
#  'InmateProgressID': 13,
#  'RehabProgID': 5,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 3,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc4')}
#
#
# {'AcadProgID': 3,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 14,
#  'InmateProgressID': 14,
#  'RehabProgID': 1,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 2,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc5')}
#
#
# {'AcadProgID': 3,
#  'AcadProgStatus': 'Pass',
#  'InmateID': 67,
#  'InmateProgressID': 15,
#  'RehabProgID': 3,
#  'RehabProgStatus': 'Pass',
#  'VocProgID': 9,
#  'VocProgStatus': 'Pass',
#  '_id': ObjectId('60686e164cdb763fda24efc6')}
#
#
# In FOR-loop:  15
# Out FOR-loop:  15
#
# Counter sequence
#
# {'_id': ObjectId('60686e164cdb763fda24efa0'), 'name': 'inmateID', 'seq': 129}
# {'_id': ObjectId('60686e164cdb763fda24efa1'), 'name': 'userID', 'seq': 0}
# {'_id': ObjectId('60686e164cdb763fda24efa7'), 'name': 'acadProjID', 'seq': 5}
# {'_id': ObjectId('60686e164cdb763fda24efad'), 'name': 'drugRehabProjID', 'seq': 5}
# {'_id': ObjectId('60686e164cdb763fda24efb7'), 'name': 'vocationalProjID', 'seq': 9}
# {'_id': ObjectId('60686e164cdb763fda24efc7'), 'name': 'inmateProjID', 'seq': 15}
